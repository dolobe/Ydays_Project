# %% [markdown]
# ### Analyse De Corrélation :

# %%
# Importing the libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the file
df = pd.read_csv('../spotify.csv', encoding='latin1')
# print(df.head())
print(df)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
columns_to_convert = ['in_spotify_playlists', 'in_spotify_charts', 'streams',
                    'in_apple_playlists', 'in_apple_charts',
                    'in_deezer_playlists', 'in_deezer_charts',
                    'in_shazam_charts']

for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')  # Convertir les valeurs non numériques en NaN

# Supprimer les lignes avec des valeurs NaN
df.dropna(subset=columns_to_convert, inplace=True)

# Agréger les mesures de popularité pour chaque chanson
df['total_popularity'] = df[columns_to_convert].sum(axis=1)

# Créer un histogramme de la popularité des chansons
plt.figure(figsize=(10, 6))
plt.hist(df['total_popularity'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Popularité totale')
plt.ylabel('Nombre de chansons')
plt.title('Distribution de la popularité des chansons')
plt.grid(True)
plt.show()

# %%
# Distribution des features
features = ['bpm', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
            'instrumentalness_%', 'liveness_%', 'speechiness_%']

plt.figure(figsize=(15, 10))
for i, feature in enumerate(features, start=1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=df[feature], color='skyblue')
    plt.title(feature.capitalize())
    plt.ylabel('')

plt.tight_layout()
plt.show()

# Identifier les chansons avec une popularité très élevée ou très basse
high_popularity_threshold = df['total_popularity'].quantile(0.95)
low_popularity_threshold = df['total_popularity'].quantile(0.05)

high_popularity_songs = df[df['total_popularity'] >= high_popularity_threshold]
low_popularity_songs = df[df['total_popularity'] <= low_popularity_threshold]

print("Chansons avec une popularité très élevée :")
print(high_popularity_songs[['track_name', 'artist(s)_name', 'total_popularity']])

print("\nChansons avec une popularité très basse :")
print(low_popularity_songs[['track_name', 'artist(s)_name', 'total_popularity']])
# Out:
# Chansons avec une popularité très élevée :
#                                             track_name  \
# 22                                    I Wanna Be Yours
# 37                                         Blank Space
# 41       Sunflower - Spider-Man: Into the Spider-Verse
# 47                                         Die For You
# 57                                          La Bachata
# 74               Quevedo: Bzrp Music Sessions, Vol. 52
# 77                           Unholy (feat. Kim Petras)
# 84                           STAY (with Justin Bieber)
# 87                                     Me Porto Bonito
# 115                                     No Role Modelz
# 134                                                505
# 152                                       Danza Kuduro
# 154                               Locked Out Of Heaven
# 164                                    Save Your Tears
# 166            Every Breath You Take - Remastered 2003
# 167                                   The Night We Met
# 169                                When I Was Your Man
# 170                                 Let Me Down Slowly
# 187                                            Circles
# 192                                  Titi Me Preguntï¿
# 246                                         Easy On Me
# 292                                   Call Out My Name
# 310       Save Your Tears (with Ariana Grande) (Remix)
# 365  Enemy (with JID) - from the series Arcane Leag...
# 368                                        LA CANCIï¿½
# 401                                            Heather
# 422                                           Yonaguni
# 433                          Levitating (feat. DaBaby)
# 516                           Kiss Me More (feat. SZA)
# 526                                             Beggin
# 555                                             Dakiti
# 565                                            deja vu
# 591                                      Before You Go
# 599                                          positions
# 614                                 you broke me first
# 619   Enemy - from the series Arcane League of Legends
# 621                                       Lucid Dreams
# 674                                         Contection
# 695                                          Adore You
# 718                                               Hope
# 790                                           Callaita
# 820                                               Iris
#
#                                       artist(s)_name  total_popularity
# 22                                    Arctic Monkeys      1.297040e+09
# 37                                      Taylor Swift      1.355971e+09
# 41                             Post Malone, Swae Lee      2.808122e+09
# 47                                        The Weeknd      1.647993e+09
# 57                                     Manuel Turizo      1.214091e+09
# 74                                 Bizarrap, Quevedo      1.356574e+09
# 77                             Sam Smith, Kim Petras      1.230685e+09
# 84                      Justin Bieber, The Kid Laroi      2.665362e+09
# 87                       Chencho Corleone, Bad Bunny      1.440767e+09
# 115                                          J. Cole      1.791022e+09
# 134                                   Arctic Monkeys      1.217135e+09
# 152                                Don Omar, Lucenzo      1.279454e+09
# 154                                       Bruno Mars      1.481352e+09
# 164                                       The Weeknd      1.591237e+09
# 166                                       The Police      1.593295e+09
# 167                                       Lord Huron      1.410109e+09
# 169                                       Bruno Mars      1.661191e+09
# 170                                    Alec Benjamin      1.374588e+09
# 187                                      Post Malone      2.132357e+09
# 192                                        Bad Bunny      1.264320e+09
# 246                                            Adele      1.406123e+09
# 292                                       The Weeknd      1.449812e+09
# 310                        Ariana Grande, The Weeknd      1.221823e+09
# 365  Imagine Dragons, League of Legends, JID, Arcane      1.223488e+09
# 368                              J Balvin, Bad Bunny      1.435135e+09
# 401                                       Conan Gray      1.301806e+09
# 422                                        Bad Bunny      1.260605e+09
# 433                                 Dua Lipa, DaBaby      1.802531e+09
# 516                                    SZA, Doja Cat      1.575484e+09
# 526                                        Mï¿½ï¿½ne      1.367820e+09
# 555                           Bad Bunny, Jhay Cortez      1.763376e+09
# 565                                   Olivia Rodrigo      1.256889e+09
# 591                                    Lewis Capaldi      1.608055e+09
# 599                                    Ariana Grande      1.252572e+09
# 614                                       Tate McRae      1.180102e+09
# 619       Imagine Dragons, League of Legends, Arcane      1.223482e+09
# 621                                       Juice WRLD      2.288711e+09
# 674                                GODZZ__-, Zakaria      1.180904e+09
# 695                                     Harry Styles      1.439206e+09
# 718                                     XXXTENTACION      1.200812e+09
# 790                                 Bad Bunny, Tainy      1.304324e+09
# 820                                The Goo Goo Dolls      1.284956e+09
#
# Chansons avec une popularité très basse :
#                                             track_name  \
# 30                                                Rush
# 58                                                 S91
# 68                                           Overdrive
# 69                        Enchanted (Taylor's Version)
# 79                                     CORAZï¿½ï¿½N VA
# 82                                   Novidade na ï¿½ï¿
# 83                 Back To December (Taylor's Version)
# 94                                      Still With You
# 104                                          New Jeans
# 112                                            LAGUNAS
# 113                            Mine (Taylor's Version)
# 123                                        Que Vuelvas
# 142                        Gol Bolinha, Gol Quadrado 2
# 144                                              QUEMA
# 150                                     Mi Bello Angel
# 185                                            Cheques
# 193             Better Than Revenge (Taylor's Version)
# 212                                   Piï¿½ï¿½man Deï¿
# 214  All The Way Live (Spider-Man: Across the Spide...
# 218                            Karma (feat. Ice Spice)
# 226                  Stand By Me (feat. Morgan Wallen)
# 228           Hummingbird (Metro Boomin & James Blake)
# 238  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 248                     Danger (Spider) (Offset & JID)
# 254                                       Mejor Que Yo
# 255                                           Curtains
# 289           Don't ever say love me (feat. RM of BTS)
# 373                        Born With A Beer In My Hand
# 379                                 Devil Donï¿½ï¿½ï¿½
# 393                                  Jhoome Jo Pathaan
# 493                                           Too Late
# 497                                                Far
# 541                                   A Tale By Quincy
# 552                          Every Angel is Terrifying
# 577                              Phantom Regret by Jim
# 681                                          Worst Day
# 797                                   Rich - Interlude
# 801                                              Crown
# 802                                     Auntie Diaries
# 807                                 Savior - Interlude
# 809  Mother I Sober (feat. Beth Gibbons of Portishead)
# 913                                   XQ Te Pones Asï¿
#
#                                         artist(s)_name  total_popularity
# 30                                         Troye Sivan        22582654.0
# 58                                             Karol G        16012302.0
# 68                                         Post Malone        14780997.0
# 69                                        Taylor Swift        39578490.0
# 79                                       Maria Becerra        43858160.0
# 82                               Mc Livinho, DJ Matt D        39709482.0
# 83                                        Taylor Swift        39229186.0
# 94                                           Jung Kook        38412143.0
# 104                                           NewJeans        29562548.0
# 112                          Jasiel Nuï¿½ï¿½ez, Peso P        39058935.0
# 113                                       Taylor Swift        36912317.0
# 123                         Carin Leon, Grupo Frontera            3783.0
# 142                                Mc Pedrinho, DJ 900        11957047.0
# 144                       Sog, Ryan Castro, Peso Pluma        11600139.0
# 150                                      Natanael Cano        31873818.0
# 185                                              Shubh        47956527.0
# 193                                       Taylor Swift        30343343.0
# 212                               Semicenk, Doï¿½ï¿½u         43522826.0
# 214                 Future, Lil Uzi Vert, Metro Boomin        37126971.0
# 218                            Taylor Swift, Ice Spice        46143435.0
# 226                            Lil Durk, Morgan Wallen        46066277.0
# 228                          James Blake, Metro Boomin        39666550.0
# 238     WizKid, Toian, Metro Boomin, Don Toliver, Beam        32761902.0
# 248                                        Offset, JID        24975879.0
# 254                    Mambo Kingz, DJ Luian, Anuel Aa        50848334.0
# 255                                         Ed Sheeran        39894321.0
# 289                                          RM, Colde        34502339.0
# 373                                      Morgan Wallen        34451191.0
# 379                                      Morgan Wallen        32527125.0
# 393  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...         1365419.0
# 493                                                SZA        49263686.0
# 497                                                SZA        51642383.0
# 541                                         The Weeknd        41925203.0
# 552                                         The Weeknd        37308685.0
# 577                                         The Weeknd        31960344.0
# 681                                             Future        50747577.0
# 797                                     Kendrick Lamar        41211190.0
# 801                                     Kendrick Lamar        42487076.0
# 802                                     Kendrick Lamar        37779738.0
# 807                                     Kendrick Lamar        37092773.0
# 809                       Kendrick Lamar, Beth Gibbons        33383349.0
# 913                                       Yandel, Feid        47094263.0
